# %% [markdown]
# ## Homework 3 - CS348 Spring 2022

# %% [markdown]
# **Description** - This assignment is intended to teach you about implementing and comparing different classification methods.

# %% [markdown]
# **Getting Started** - You should complete the assignment using your own installation of Python 3 and the scikit-learn, numpy, and matplotlib packages. You can use other plotting packages as long as the graphics are clear and appear in the correct location in the notebook. Download the assignment from Moodle and unzip the file. This will create a directory with this file, 'hw3.ipynb', and a 'data' directory that contains all the required data files.

# %% [markdown]
# **Datasets** - This assignment uses four datasets that you will find in the data folder. For each dataset you have been provided with the following:
# - complete dataset inputs
# - complete dataset outputs
# - training inputs
# - training outputs
# - testing inputs
# - testing outputs
#
# You should use only the training data to train your models, and only the testing data to test your models. The train/test split was performed by randomly shuffling the order of the data, then randomly selecting 80% of the data cases for training and leaving the rest for testing.

# %% [markdown]
# **Deliverables** -  The assignment has a single deliverable: this jupyter notebook file. Please answer all questions in the body of this file. Code should be written in a clean and organized fashion, and should be able to be run by the instructor and the TA by executing each code cell in order from top to bottom. It is strongly suggested that you reset the notebook and execute every cell in order before submitting.

# %% [markdown]
# **Academic Honesty Statement** — Copying solutions from external sources (books,
# web pages, etc.) or other students is considered cheating. Sharing your solutions with
# other students is considered cheating. Posting your code to public repositories such as
# GitHub is also considered cheating. Any detected cheating will result in a grade of 0 on
# the assignment for all students involved, and potentially a grade of F in the course.
#
# This academic honesty statement does not restrict you from reading official documentation or using other web resources for understanding the syntax of python, related data science libraries, or properties of distributions.

# %%
# Do not import any other libraries other than those listed here.  
import numpy as np
import sklearn
import matplotlib.pyplot as plt
from sklearn.linear_model import RidgeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
# %matplotlib inline

# %% [markdown]
# # Problem 1 - Comparing classifiers

# %% [markdown]
# In this problem you will compare and analyze the performance of four classifiers across four datasets. You will implement linear, KNN, random forest, and naive bayesian classifiers using scikit-learn. Please use the specific classifiers listed below.
#
# - https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.RidgeClassifier.html
# - https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
# - https://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.GaussianNB.html
# - https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html

# %% [markdown]
# **1.1)** (14 points)
# For each of the four datasets do the following:
# - Train a linear classifier (RidgeClassifier) on the training data. Use $\alpha = 1.0$, and the 'lsqr' solver.
# - Use the trained models to predict the outputs of the **training** data, and measure the percentage of inputs that were classified correctly ("training accuracy").
# - Use the trained models to predict the outputs of the **test** data, and measure the percentage of inputs that were classified correctly ("test accuracy").
#
# Display a plot showing the datasets along the x-axis with one line showing the training accuracy and another line showing the test accuracy for each dataset.

# %%
# Part 1.1 Solution

# --- write code here ---
# import the train data for dataset1
data1_trainX = np.loadtxt('/Users/eeshaarabhavi/Downloads/CS348Homework/hw3/data/dataset1_train_X.csv')
data1_trainY = np.loadtxt('/Users/eeshaarabhavi/Downloads/CS348Homework/hw3/data/dataset1_train_Y.csv')
# import the test data for dataset1
data1_testX = np.loadtxt('/Users/eeshaarabhavi/Downloads/CS348Homework/hw3/data/dataset1_test_X.csv')
data1_testY = np.loadtxt('/Users/eeshaarabhavi/Downloads/CS348Homework/hw3/data/dataset1_test_Y.csv')
# import the train data for dataset2
data2_trainX = np.loadtxt('/Users/eeshaarabhavi/Downloads/CS348Homework/hw3/data/dataset2_train_X.csv')
data2_trainY = np.loadtxt('/Users/eeshaarabhavi/Downloads/CS348Homework/hw3/data/dataset2_train_Y.csv')
# import the test data for dataset2
data2_testX = np.loadtxt('/Users/eeshaarabhavi/Downloads/CS348Homework/hw3/data/dataset2_test_X.csv')
data2_testY = np.loadtxt('/Users/eeshaarabhavi/Downloads/CS348Homework/hw3/data/dataset2_test_Y.csv')
# import the train data for dataset3
data3_trainX = np.loadtxt('/Users/eeshaarabhavi/Downloads/CS348Homework/hw3/data/dataset3_train_X.csv')
data3_trainY = np.loadtxt('/Users/eeshaarabhavi/Downloads/CS348Homework/hw3/data/dataset3_train_Y.csv')
# import the test data for dataset3
data3_testX = np.loadtxt('/Users/eeshaarabhavi/Downloads/CS348Homework/hw3/data/dataset3_test_X.csv')
data3_testY = np.loadtxt('/Users/eeshaarabhavi/Downloads/CS348Homework/hw3/data/dataset3_test_Y.csv')
# import the train data for dataset4
data4_trainX = np.loadtxt('/Users/eeshaarabhavi/Downloads/CS348Homework/hw3/data/dataset4_train_X.csv')
data4_trainY = np.loadtxt('/Users/eeshaarabhavi/Downloads/CS348Homework/hw3/data/dataset4_train_Y.csv')
# import the test data for dataset4
data4_testX = np.loadtxt('/Users/eeshaarabhavi/Downloads/CS348Homework/hw3/data/dataset4_test_X.csv')
data4_testY = np.loadtxt('/Users/eeshaarabhavi/Downloads/CS348Homework/hw3/data/dataset4_test_Y.csv')

# create RidgeClassifier for each dataset
rc1 = RidgeClassifier(alpha = 1.0, solver = 'lsqr')
rc2 = RidgeClassifier(alpha = 1.0, solver = 'lsqr')
rc3 = RidgeClassifier(alpha = 1.0, solver = 'lsqr')
rc4 = RidgeClassifier(alpha = 1.0, solver = 'lsqr')

# train RidgeClassifier on training data of each dataset
rc1 = rc1.fit(data1_trainX, data1_trainY)
rc2 = rc2.fit(data2_trainX, data2_trainY)
rc3 = rc3.fit(data3_trainX, data3_trainY)
rc4 = rc4.fit(data4_trainX, data4_trainY)

# create two arrays that store all of the accuracy values for both training and test scores
trainrc = []
testrc =[]

# predict outputs for all four datasets and store into proper array
trainrc.append(rc1.score(data1_trainX, data1_trainY))
testrc.append(rc1.score(data1_testX, data1_testY))

trainrc.append(rc2.score(data2_trainX, data2_trainY))
testrc.append(rc2.score(data2_testX, data2_testY))

trainrc.append(rc3.score(data3_trainX, data3_trainY))
testrc.append(rc3.score(data3_testX, data3_testY))

trainrc.append(rc4.score(data4_trainX, data4_trainY))
testrc.append(rc4.score(data4_testX, data4_testY))

# create array that holds dataset names for x-axis
datasets = ['Dataset 1', 'Dataset 2', 'Dataset 3', 'Dataset 4']

# plot the four prediction outputs
plt.plot(datasets, trainrc, color = 'lightblue', marker = 'o', label = 'Training Accuracy')
plt.plot(datasets, testrc, color = 'pink', marker = 'o', label = 'Testing Accuracy')
plt.title('Linear Classifier (RidgeClassifier)', fontsize = 12)
plt.xlabel('Dataset')
plt.ylabel('Accuracy Percentage')
plt.legend()
plt.show()

# %% [markdown]
# **1.2)** (14 points)
# For each of the four datasets do the following:
# - Train a k-nearest neighbors classifier (KNeighborsClassifier) on the training data. Use $k=5$.
# - Use the trained models to predict the outputs of the **training** data, and measure the percentage of inputs that were classified correctly.
# - Use the trained models to predict the outputs of the **test** data, and measure the percentage of inputs that were classified correctly.
#
# Display a plot showing the datasets along the x-axis with one line showing the training accuracy and another line showing the test accuracy for each dataset.

# %%
# Part 1.2 Solution

# --- write code here ---
# create KNeighborsClassifier for each dataset
knn1 = KNeighborsClassifier(n_neighbors = 5)
knn2 = KNeighborsClassifier(n_neighbors = 5)
knn3 = KNeighborsClassifier(n_neighbors = 5)
knn4 = KNeighborsClassifier(n_neighbors = 5)

# train KNeighborsClassifier on training data of each dataset
knn1 = knn1.fit(data1_trainX, data1_trainY)
knn2 = knn2.fit(data2_trainX, data2_trainY)
knn3 = knn3.fit(data3_trainX, data3_trainY)
knn4 = knn4.fit(data4_trainX, data4_trainY)

# create two arrays that store all of the accuracy values for both training and test scores
trainknn = []
testknn =[]

# predict outputs for all four datasets and store into proper array
trainknn.append(knn1.score(data1_trainX, data1_trainY))
testknn.append(knn1.score(data1_testX, data1_testY))

trainknn.append(knn2.score(data2_trainX, data2_trainY))
testknn.append(knn2.score(data2_testX, data2_testY))

trainknn.append(knn3.score(data3_trainX, data3_trainY))
testknn.append(knn3.score(data3_testX, data3_testY))

trainknn.append(knn4.score(data4_trainX, data4_trainY))
testknn.append(knn4.score(data4_testX, data4_testY))

# plot the four prediction outputs
plt.plot(datasets, trainknn, color = 'lightblue', marker = 'o', label = 'Training Accuracy')
plt.plot(datasets, testknn, color = 'pink', marker = 'o', label = 'Testing Accuracy')
plt.title('K-Nearest Neighbors Classifier (KNeighborsClassifier)', fontsize = 12)
plt.xlabel('Dataset')
plt.ylabel('Accuracy Percentage')
plt.legend()
plt.show()

# %% [markdown]
# **1.3)** (14 points)
# For each of the four datasets do the following:
# - Train a gaussian naive Bayes classifier (GaussianNB) on the training data.
# - Use the trained models to predict the outputs of the **training** data, and measure the percentage of inputs that were classified correctly.
# - Use the trained models to predict the outputs of the **test** data, and measure the percentage of inputs that were classified correctly.
#
# Display a plot showing the datasets along the x-axis with one line showing the training accuracy and another line showing the test accuracy for each dataset.

# %%
# Part 1.3 Solution

# --- write code here ---
# create GaussianNB for each dataset
nb1 = GaussianNB()
nb2 = GaussianNB()
nb3 = GaussianNB()
nb4 = GaussianNB()

# train GaussianNB on training data of each dataset
nb1 = nb1.fit(data1_trainX, data1_trainY)
nb2 = nb2.fit(data2_trainX, data2_trainY)
nb3 = nb3.fit(data3_trainX, data3_trainY)
nb4 = nb4.fit(data4_trainX, data4_trainY)

# create two arrays that store all of the accuracy values for both training and test scores
trainnb = []
testnb =[]

# predict outputs for all four datasets and store into proper array
trainnb.append(nb1.score(data1_trainX, data1_trainY))
testnb.append(nb1.score(data1_testX, data1_testY))

trainnb.append(nb2.score(data2_trainX, data2_trainY))
testnb.append(nb2.score(data2_testX, data2_testY))

trainnb.append(nb3.score(data3_trainX, data3_trainY))
testnb.append(nb3.score(data3_testX, data3_testY))

trainnb.append(nb4.score(data4_trainX, data4_trainY))
testnb.append(nb4.score(data4_testX, data4_testY))

# plot the four prediction outputs
plt.plot(datasets, trainnb, color = 'lightblue', marker = 'o', label = 'Training Accuracy')
plt.plot(datasets, testnb, color = 'pink', marker = 'o', label = 'Testing Accuracy')
plt.title('Gaussian Naive Bayes Classifier (GaussianNB)', fontsize = 12)
plt.xlabel('Dataset')
plt.ylabel('Accuracy Percentage')
plt.legend()
plt.show()

# %% [markdown]
# **1.4)** (14 points)
# For each of the four datasets do the following:
# - Train a random forest classifier (RandomForestClassifier) on the training data. Use `n_estimators=50`.
# - Use the trained models to predict the outputs of the **training** data, and measure the percentage of inputs that were classified correctly.
# - Use the trained models to predict the outputs of the **test** data, and measure the percentage of inputs that were classified correctly.
#
# Display a plot showing the datasets along the x-axis with one line showing the training accuracy and another line showing the test accuracy for each dataset.

# %%
# Part 1.4 Solution

# --- write code here ---
# create RandomForestClassifier for each dataset
rfc1 = RandomForestClassifier(n_estimators = 50)
rfc2 = RandomForestClassifier(n_estimators = 50)
rfc3 = RandomForestClassifier(n_estimators = 50)
rfc4 = RandomForestClassifier(n_estimators = 50)

# train RandomForestClassifier on training data of each dataset
rfc1 = rfc1.fit(data1_trainX, data1_trainY)
rfc2 = rfc2.fit(data2_trainX, data2_trainY)
rfc3 = rfc3.fit(data3_trainX, data3_trainY)
rfc4 = rfc4.fit(data4_trainX, data4_trainY)

# create two arrays that store all of the accuracy values for both training and test scores
trainrfc = []
testrfc =[]

# predict outputs for all four datasets and store into proper array
trainrfc.append(rfc1.score(data1_trainX, data1_trainY))
testrfc.append(rfc1.score(data1_testX, data1_testY))

trainrfc.append(rfc2.score(data2_trainX, data2_trainY))
testrfc.append(rfc2.score(data2_testX, data2_testY))

trainrfc.append(rfc3.score(data3_trainX, data3_trainY))
testrfc.append(rfc3.score(data3_testX, data3_testY))

trainrfc.append(rfc4.score(data4_trainX, data4_trainY))
testrfc.append(rfc4.score(data4_testX, data4_testY))

# plot the four prediction outputs
plt.plot(datasets, trainrfc, color = 'lightblue', marker = 'o', label = 'Training Accuracy')
plt.plot(datasets, testrfc, color = 'pink', marker = 'o', label = 'Testing Accuracy')
plt.title('Random Forest Classifier (RandomForestClassifier)', fontsize = 12)
plt.xlabel('Dataset')
plt.ylabel('Accuracy Percentage')
plt.legend()
plt.show()

# %% [markdown]
# **1.5)** (14 points) Display a single plot showing the test accuracy for all four classifiers across all four datasets. Make sure to include a legend in the plot.

# %%
# Part 1.5 Solution

# --- write code here ---
plt.plot(datasets, testrc, color = 'pink', marker = 'o', label = 'Linear')
plt.plot(datasets, testknn, color = 'lightgreen', marker = 'o', label = 'K-Nearest Neighbor')
plt.plot(datasets, testnb, color = 'lightblue', marker = 'o', label = 'Gaussian Naive Bayes')
plt.plot(datasets, testrfc, color = 'gold', marker = 'o', label = 'Random Forest')
plt.title('Test Accuracies for all Four Classifiers Across All Four Datasets')
plt.xlabel('Dataset')
plt.ylabel('Accuracy Percentage')
plt.legend()
plt.show()

# %% [markdown]
# **1.6)** (30 points) These datasets have qualities that make them challenging for certain types of classifiers. Analyzing the datasets, the plots you made above, and any other plots you might find helpful, do your best to explain the results you have obtained. You should consider the difference between classifiers applied to the same dataset, as well as how a given classifier performs across the datasets. For each data set, describe key characteristics of the data set and why those characteristics led to the observed differences in performance among the four methods. (<6 sentences each):
#
# Dataset 1:
# This dataset has some x values that are negative in both the training and testing data. Although the Random Forest Classifier seems to be the best in terms of training accuracy for each dataset, this is not always the case since Random Forests tend to overfit so tuning the hyperparameter of nestimators would give a more accurate model for each dataset. The x data in this dataset has dimension of 2 which is countered by there being a large number of datapoints which makes KNN a valid model but overfitting is always still possible with KNN. In contrast, Gaussian Naive Bayes Classifiers are very good at handling large amounts of data while also not overfitting. Linear Classifier only is effective with data in datasets that are linear in nature but after viewing this dataset, I observed that the data are not exactly linear in nature. Due to this, the linear classifier did not accurately model both the training and test data.
#
# Dataset 2:
# This dataset has no negative x values in both the training and the testing data unlike Dataset 1. The Random Forest Classifier training accuracy for all of the datasets seems to be similar and this could be because the hyperparameter nestimators needs to be tuned for each dataset so that the Random Forest Classifier does not overfit the data. Due to a large amount of datapoints in the dataset compensating for the dimensionality of the data, this data can be modeled using KNN classifier but there is still also a possibility of overfitting. Additionally, the testing accuracy for the Linear Classifier being high tells us that the dataset is more linear than the other datasets. The Gaussian Naive Bayes Classifier has the same test and training accuracies as the Linear Classifier and this could be because they are both the best model for this dataset.
#
# Dataset 3:
# This dataset has a large dimensionality but the number datapoints in the dataset are not exponentially larger which means that KNN classifier cannot be a good model for the data. Further more, as stated above, the Random Forest Classifier's hyperparameter nestimators needs to tuned for this dataset inorder for the classifier to not overfit the data. This is because the Random Forest Classifier's training accuracy for all of the datasets is very high which means that the classifier's hyperparameter has not been tuned for each dataset. The Linear Classifier's testing accuracy being low could be because the data was not linear in nature. Thus using a Gaussian Naive Bayes Classifier would give a more valid model for this dataset.
#
# Dataset 4:
# This dataset has a large dimensionality but again like dataset 3, the number of datapoints in the dataset are not exponentially larger which means that the KNN classifier cannot be a good modeel for the data. Furthermore, as mentioned before, the Random Forest Classifier training accuracy for all of the datasets seems to be similar and this could be because the hyperparameter nestimators is not tuned for the dataset to make sure that the Random Forest Classifier does not overfit the data. The Gaussian Naive Bayes Classifier and the Linear Classifier have the same testing accuracy but not the same training accuracy. Since testing accuracy is more important than training accuracy when figuring out which model is the best model for the dataset, both the Linear Classifier and the Gaussian Naive Bayes Classifier would probably be valid models.
